# %% [markdown]
# # Session 7

# %% [markdown]
# ### Dataset
#
# Option1 - U have train folder & inside it 2 folders, cat & dog folders.

# %% [markdown]
# Option2 - U have train folder & all images of cats & dogs mixed within it. In this case label mapping is given in a csv file. It has file name of image & its corresponding label e.g. dog is present in csv file.
#
# Images in a folder & labels come via dataframe.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
